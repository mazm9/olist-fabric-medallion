# %%
base_path = "Files"

files = {
    "bronze_customers": "olist_customers_dataset.csv",
    "bronze_orders": "olist_orders_dataset.csv",
    "bronze_order_items": "olist_order_items_dataset.csv",
    "bronze_payments": "olist_order_payments_dataset.csv",
    "bronze_products": "olist_products_dataset.csv"
}

for table_name, file_name in files.items():
    
    path = f"{base_path}/{file_name}"
    
    df = (
        spark.read
        .option("header", True)
        .option("inferSchema", True)
        .csv(path)
    )
    
    print(f"Loading {table_name}")
    print(f"Rows: {df.count()}")
    
    (
        df.write
        .mode("overwrite")
        .format("delta")
        .saveAsTable(table_name)
    )
# Out:
# StatementMeta(, 6cc81b5b-c928-4192-b64e-e8a4f508e940, 3, Finished, Available, Finished, False)
# Loading bronze_customers
# Rows: 99441
# Loading bronze_orders
# Rows: 99441
# Loading bronze_order_items
# Rows: 112650
# Loading bronze_payments
# Rows: 103886
# Loading bronze_products
# Rows: 32951
